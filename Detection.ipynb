# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
! pip install -r /content/detection_model/requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/detection_model/requirements.txt'

# %%
! git clone https://github.com/m-kichik/warp-d_cfg
# Out:
# Cloning into 'warp-d_cfg'...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
! pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/79.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/79.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/79.7 kB ? eta -:--:--
#      ----------------------------- -------- 61.4/79.7 kB 409.6 kB/s eta 0:00:01
#      -------------------------------------- 79.7/79.7 kB 445.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/78.2 kB ? eta -:--:--
#    ---------------------------------------- 78.2/78.2 kB 2.2 MB/s eta 0:00:00
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.12-py3-none-any.whl size=102982 sha256=fd1248ba4c2a7f39180317c224a00d18ad5984543dfef1922299688dd1cfb73e
#   Stored in directory: c:\users\palut\appdata\local\pip\cache\wheels\f3\eb\e9\819c2d9eac90204eec8579430759f75a1d6dbe4cd0b93f53bc
# Successfully built kaggle
# ...

# %%
! mkdir ~/.kaggle
# Out:
# The syntax of the command is incorrect.

# %%
! cp kaggle.json ~/.kaggle/
# Out:
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.

# %%
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.

# %%
! kaggle datasets download -d parohod/warp-waste-recycling-plant-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/parohod/warp-waste-recycling-plant-dataset
#   0%|          | 0.00/806M [00:00<?, ?B/s]
#   0%|          | 1.00M/806M [00:02<29:02, 484kB/s]
#   0%|          | 2.00M/806M [00:04<29:36, 475kB/s]
#   0%|          | 3.00M/806M [00:06<29:44, 472kB/s]
#   0%|          | 4.00M/806M [00:08<30:03, 466kB/s]
#   1%|          | 5.00M/806M [00:11<30:04, 465kB/s]
#   1%|          | 6.00M/806M [00:13<29:58, 466kB/s]
#   1%|          | 7.00M/806M [00:15<30:11, 462kB/s]
#   1%|          | 8.00M/806M [00:17<30:01, 464kB/s]
#   1%|          | 9.00M/806M [00:20<29:56, 465kB/s]
#   1%|          | 10.0M/806M [00:22<29:47, 467kB/s]
#   1%|▏         | 11.0M/806M [00:24<29:42, 468kB/s]
#   1%|▏         | 12.0M/806M [00:26<29:37, 468kB/s]
#   2%|▏         | 13.0M/806M [00:29<29:43, 466kB/s]
#   2%|▏         | 14.0M/806M [00:31<29:38, 467kB/s]
#   2%|▏         | 15.0M/806M [00:33<29:35, 467kB/s]
#   2%|▏         | 16.0M/806M [00:35<29:33, 467kB/s]
# ...

# %%
! unzip warp-waste-recycling-plant-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-43-15.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-46-17.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-46-28.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-46-51.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-48-33.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-51-12.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-57-50.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_08-59-44.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_09-01-38.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_09-05-13.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_09-05-25.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_09-06-44.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_09-08-04.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_09-13-10.jpg
#   inflating: Warp-D/train/images/POSAD_1_11-Sep_09-15-49.jpg
# ...

# %%
from yolov5 import train

# %%
train.run(
    # weights=''
    cfg='/content/yolov5/models/yolov5n.yaml',
    data='/content/warp-d_cfg/warp-d_config.yaml',
    epochs=10,
    batch_size=4,
    imgsz=640,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train.run(
#       2     # weights=''
#       3     cfg='/content/yolov5/models/yolov5n.yaml',
#       4     data='/content/warp-d_cfg/warp-d_config.yaml',
#       5     epochs=10,
#       6     batch_size=4,
#       7     imgsz=640,
#       8 )
#
# NameError: name 'train' is not defined
